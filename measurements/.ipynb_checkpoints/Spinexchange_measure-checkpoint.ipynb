# %% [markdown]
# # Measuring the spin exchange rate

# %%
#import statements
import numpy as np
import matplotlib.pyplot as plt
import one_ring.base.fitting_tools as fitt
import one_ring.daq.nidaqmx_tools as ndaq
import one_ring.daq.stanford_research_systems as srs
import importlib
import one_ring.base.signal_tools as sit
from one_ring.base.pint_units import ureg
import one_ring.base.h5py_tools as h5t
import scipy.constants
from scipy import constants
# %matplotlib widget
import time as tm
import pyvisa as visa
import one_ring.daq.visa_instruments as nvisa
plt.style.use("dark_background")
import pandas as pd
import one_ring.daq.thorlabs as thor
import one_ring.daq.tektronix as tek
import one_ring.base.pandas_tools as pdt

# %%
bw = 482*ureg.kHz
f_res = 1*ureg.Hz
SA = ndaq.SpectrumAnalyzer(bw, f_res)

# %%
SA.configure_channels()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Input channel', options=('Dev1/ai0', 'Dev1/ai1', 'Dev1/ai2…

# %%
this is the probe with pump on noise. no field compensation.

# %%
SA.display()
# Out:
# HBox(children=(ToggleButton(value=False, button_style='success', description='Acquire', icon='play'),))
# Output()

# %%
PDB_Monitor.close()

# %%
fs = 1 * ureg.kHz #f3dB is 159kHz
dt = 1/fs
PDB_Monitor = ndaq.DAQViewer(dt)

# %%
PDB_Monitor.configure_channels()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Input channel', options=('Dev1/ai0', 'Dev1/ai1', 'Dev1/ai2…

# %%
PDB_Monitor.display()
# Out:
# HBox(children=(ToggleButton(value=False, button_style='success', description='Acquire', icon='play'), Button(b…
# Output()

# %%
a1 = 2.04
a2 = 1.8
(a1 - a2)
# Out:
# 0.24

# %%
T = (0.03054 - 0.01065 ) * ureg.s
T
# Out:
# <Quantity(0.01989, 'second')>

# %%
(1/0.02/ureg.s).to(ureg.Hz)
# Out:
# <Quantity(50.0, 'hertz')>

# %%
(PDB_Monitor.get_data().max() + PDB_Monitor.get_data().min())/2

# %%
FGM.close()
# Out:
# C:\Users\labuser_L213\miniforge3\envs\one_ring\lib\site-packages\nidaqmx\task\_task.py:350: DaqResourceWarning: Attempted to close NI-DAQmx task of name "_unnamedTask<3>" but task was already closed.
#   warnings.warn(
# C:\Users\labuser_L213\miniforge3\envs\one_ring\lib\site-packages\nidaqmx\task\_task.py:350: DaqResourceWarning: Attempted to close NI-DAQmx task of name "_unnamedTask<2>" but task was already closed.
#   warnings.warn(

# %%
fs = 1 * ureg.MHz
acq_time = 1*ureg.s
ao_sample_rate = fs
FGM = ndaq.FiniteGenerationAndMeasurement(fs,acq_time, ao_sample_rate)

# %%
FGM.configure_channels()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Input channel', options=('Dev1/ai0', 'Dev1/ai1', 'Dev1/ai2…
# VBox(children=(HBox(children=(Dropdown(description='Output channel', options=('Dev1/ao0', 'Dev1/ao1'), style=D…

# %%
fs_out = FGM.configure_timings()

# %%
samples_per_call = int(round(1*ureg.s*fs_out))
yi = 0
yf = 0.05
transition_time = 10e-10
hold_time = 3*ureg.us
signal = sit.TanhWindow(fs_out, 2000, yi, yf, transition_time, hold_time,t_start=0.1)

# %%
interval = 1
signal_x, signal_y = signal.generate_for(interval)

# %%
FGM.configure_tasks(signal_y)

# %%
FGM.start()

# %%
read_data = FGM.read(blocking=True)

# %%
FGM.stop()

# %%
data = read_data[0,:]
t_array = FGM.ai_task.generate_time(read_data.size)

# %%
fig, ax = plt.subplots(figsize=(8,4))
#ax.plot(signal_x, signal_y,label='Analogue Out')
ax.plot(t_array, data,label='Measured Voltage')
#ax.plot(signal_x, signal_y,label='Analogue Out')
#ax.plot(signal_x, data,label='Measured Voltage')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Voltage [V]')
ax.axvline(0.1)
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(1/((0.12883 - 0.10889) * ureg.s)).to(ureg.Hz)
# Out:
# <Quantity(50.1504514, 'hertz')>

# %%
a1 = -1.03
a2 = -1.08
(a1 - a2)
# Out:
# 0.050000000000000044

# %%
df = pd.DataFrame(data,t_array.m, columns=['Voltage'])
end_series = (0.1*ureg.s + (2000*ureg.us)).to(ureg.s).m
fid_df = df[(df.index>=0.099999) & (df.index < end_series)]

# %%
fitter = fitt.T2DecayFitter()

# %%
fit =fitter.fit(fid_df.index.to_numpy(), fid_df['Voltage'].to_numpy(),guess=(0.08,41000,0,0,1,41000))
# Out:
# C:\Users\labuser_L213\one-ring-base\one_ring\base\fitting_tools.py:1130: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, xm, ym, p0=guess, bounds=bounds,

# %%
fig, ax = plt.subplots()
ax.plot(fid_df.index, fid_df,label='AO')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Voltage [V]')
ax.legend()
fit.plot_fit(fkwargs={'alpha':0.8})
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(1/((0.1000526 - 0.10002821) * ureg.s)).to(ureg.Hz)
# Out:
# <Quantity(41000.41, 'hertz')>

# %%
fit.fit_parameters
# Out:
# {'amp': 0.08,
#  'freq': 41000.0,
#  'phase': <Quantity(0.0, 'radian')>,
#  'slope': 1.033285364223821,
#  'offset': -0.18696354678928717,
#  'inv_T2': 41000.0}

# %%
def larmor(B):
    return (scipy.constants.physical_constants['electron gyromagn. ratio over 2 pi'][0] * ureg.MHz / ureg.T/ 4 * B).to(ureg.kHz)

# %%
(1/larmor(10*ureg.uT)).to(ureg.s)

# %%
((154.60-149.55) * ureg.mA) / (0.1 * ureg.V)

# %%
5 * ureg.uT / (0.2*ureg.uT/ureg.mA)
